# %% [markdown]
# Install VADER from [VADER-Sentiment-Analysis](https://github.com/cjhutto/vaderSentiment)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install vaderSentiment
# Out:
# ...
#      |████████████████████████████████| 125 kB 6.3 MB/s
# ...

# %% [markdown]
# Import all necessary packages

# %%
import pandas as pd
import numpy as np
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from sklearn.metrics import accuracy_score
import time

# %% [markdown]
# Read data from dataset (xlsx file)

# %%
data = pd.read_excel (r'/content/drive/MyDrive/SentimentAnalysisPackages /Notebooks/Dataset02/Dataset.xlsx')

# %% [markdown]
# Run the model on the dataset

# %%
x = data['clean_comment']
y = data['category']
x = np.array(x)
y = np.array(y)

analyzer = SentimentIntensityAnalyzer()

vader_sentiment = []

start_time = time.process_time()

for sen in x:

    score = analyzer.polarity_scores(str(sen))

    if score['compound'] >= 0.05:
        vader_sentiment.append(1)
    elif score['compound'] <= -0.05:
        vader_sentiment.append(-1)
    else:
        vader_sentiment.append(0)

prediction = np.array(vader_sentiment)

end_time = time.process_time()

# %% [markdown]
# Print accuracy score

# %%
accuracy_score(y, prediction)
# Out:
# 0.6443931380708207

# %% [markdown]
# Print required time

# %%
print("Required Time: ", (end_time-start_time), "seconds")
# Out:
# Required Time:  18.716250493 seconds

# %% [markdown]
# Size of the dataset

# %%
data.shape
# Out:
# (37249, 2)
